# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("../data/Sample - Superstore.csv")
print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../data/Sample - Superstore.csv")
#       2 print("Dataset loaded successfully!")
#       3 print("Rows:", df.shape[0])
#       4 print("Columns:", df.shape[1])
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv("../data/Sample - Superstore.csv")

print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../data/Sample - Superstore.csv")
#       2
#       3 print("Dataset loaded successfully!")
#       4 print("Rows:", df.shape[0])
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("../data/sample - Superstore.csv")

print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("../data/sample - Superstore.csv")
#       2
#       3 print("Dataset loaded successfully!")
#       4 print("Rows:", df.shape[0])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os

print(os.getcwd())
print(os.listdir("../data"))
# Out:
# C:\Users\LENOVO L490\anaconda3\apexplanet_task1\notebooks
# ['.ipynb_checkpoints', 'Sample - Superstore.csv']

# %%
import pandas as pd

file_path = "../data/Sample - Superstore.csv"
df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2
#       3 file_path = "../data/Sample - Superstore.csv"
# ----> 4 df = pd.read_csv(file_path)
#       5
#       6 print("Dataset loaded successfully!")
#       7 print("Rows:", len(df))
#
# ...

# %%
df = pd.read_csv("../data/Sample - Superstore.csv", encoding="latin1")

print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../data/Sample - Superstore.csv", encoding="latin1")
#       2
#       3 print("Dataset loaded successfully!")
#       4 print("Rows:", df.shape[0])
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

df = pd.read_csv("../data/Sample - Superstore.csv", encoding="latin1")

print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Dataset loaded successfully!
# Rows: 9994
# Columns: 21

# %%
print("Dataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
print("Duplicate Rows:",df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()

print("Duplicates after cleaning:",df.duplicated().sum())
# Out:
# Duplicates after cleaning: 0

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("../data/Sample - Superstore.csv", encoding="latin1")

df = df.drop_duplicates()

df["Order Date"] = pd.to_datetime(df["Order Date"], errors="coerce")
df["Ship Date"] = pd.to_datetime(df["Ship Date"], errors="coerce")

print("Dataset loaded and dates converted successfully!")
print(df[["Order Date", "Ship Date"]].dtypes)
# Out:
# Dataset loaded and dates converted successfully!
# Order Date    datetime64[us]
# Ship Date     datetime64[us]
# dtype: object

# %%
print("Missing Values in each column:")
print(df.isnull().sum())
# Out:
# Missing Values in each column:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
missing = df.isnull().sum()
print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %%
Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["Sales"] < lower_bound) | (df["Sales"] > upper_bound)]

print("Number of Sales outliers:", len(outliers))
# Out:
# Number of Sales outliers: 1167

# %%
Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_cleaned = df[
    (df["Sales"] >= lower_bound) &
    (df["Sales"] <= upper_bound)
].copy()

print("Original rows:", len(df))
print("Rows after removing Sales outliers:", len(df_cleaned))
print("Rows removed:", len(df) - len(df_cleaned))
# Out:
# Original rows: 9994
# Rows after removing Sales outliers: 8827
# Rows removed: 1167

# %%
df_cleaned.to_csv("../data/Superstore_Cleaned.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
print("Cleaned dataset shape:", df_cleaned.shape)
df_cleaned.head()
# Out:
# Cleaned dataset shape: (8827, 21)
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
# ...

# %%
df_cleaned.describe()
# Out:
#             Row ID                  Order Date                   Ship Date  \
# count  8827.000000                        8827                        8827
# mean   5016.375892  2016-05-02 15:45:12.541067  2016-05-06 14:57:05.036818
# min       1.000000         2014-01-03 00:00:00         2014-01-07 00:00:00
# 25%    2508.500000         2015-05-28 00:00:00         2015-05-31 00:00:00
# 50%    5028.000000         2016-07-01 00:00:00         2016-07-03 00:00:00
# 75%    7517.500000         2017-05-15 00:00:00         2017-05-19 00:00:00
# max    9994.000000         2017-12-30 00:00:00         2018-01-05 00:00:00
# std    2888.406540                         NaN                         NaN
#
#         Postal Code        Sales     Quantity     Discount       Profit
# count   8827.000000  8827.000000  8827.000000  8827.000000  8827.000000
# mean   55373.635663    92.864853     3.608587     0.157606    11.198644
# min     1040.000000     0.444000     1.000000     0.000000 -1181.282400
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8827 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         8827 non-null   int64
#  1   Order ID       8827 non-null   str
#  2   Order Date     8827 non-null   datetime64[us]
#  3   Ship Date      8827 non-null   datetime64[us]
#  4   Ship Mode      8827 non-null   str
#  5   Customer ID    8827 non-null   str
#  6   Customer Name  8827 non-null   str
#  7   Segment        8827 non-null   str
#  8   Country        8827 non-null   str
#  9   City           8827 non-null   str
#  10  State          8827 non-null   str
#  11  Postal Code    8827 non-null   int64
#  12  Region         8827 non-null   str
#  13  Product ID     8827 non-null   str
#  14  Category       8827 non-null   str
#  15  Sub-Category   8827 non-null   str
#  16  Product Name   8827 non-null   str
#  17  Sales          8827 non-null   float64
# ...

# %%
plt.figure(figsize=(8, 5))

plt.hist(df_cleaned["Sales"], bins=30)

plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.figure(figsize=(8, 5))
#       2
#       3 plt.hist(df_cleaned["Sales"], bins=30)
#       4
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.hist(df_cleaned["Sales"], bins=30)

plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

sns.boxplot(x=df_cleaned["Sales"])

plt.title("Boxplot of Sales")
plt.xlabel("Sales")

plt.show()

# %%
import matplotlib.pyplot as plt

category_counts = df_cleaned["Category"].value_counts()

plt.figure(figsize=(8, 5))
plt.bar(category_counts.index, category_counts.values)

plt.title("Number of Orders by Category")
plt.xlabel("Category")
plt.ylabel("Number of Orders")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

numeric_cols = df_cleaned.select_dtypes(include=np.number)

plt.figure(figsize=(10, 6))

sns.heatmap(
    numeric_cols.corr(),
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Correlation Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt

monthly_sales = (
    df_cleaned
    .set_index("Order Date")
    .resample("ME")["Sales"]
    .sum()
)

plt.figure(figsize=(12, 5))
plt.plot(monthly_sales.index, monthly_sales.values)

plt.title("Monthly Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
print("Total Sales:", round(df_cleaned["Sales"].sum(), 2))
print("Total Profit:", round(df_cleaned["Profit"].sum(), 2))
# Out:
# Total Sales: 819718.06
# Total Profit: 98850.43

# %%
category_sales = df_cleaned.groupby("Category")["Sales"].sum().sort_values(ascending=False)

print(category_sales)
print("\nBest Category:", category_sales.idxmax())
# Out:
# Category
# Office Supplies    343425.0040
# Furniture          247877.6984
# Technology         228415.3530
# Name: Sales, dtype: float64
#
# Best Category: Office Supplies

# %%
region_sales = df_cleaned.groupby("Region")["Sales"].sum().sort_values(ascending=False)

print(region_sales)
print("\nBest Region:", region_sales.idxmax())
# Out:
# Region
# West       275810.2625
# East       232887.4840
# Central    183440.9134
# South      127579.3955
# Name: Sales, dtype: float64
#
# Best Region: West

# %%
category_profit = df_cleaned.groupby("Category")["Profit"].sum().sort_values(ascending=False)

print(category_profit)
print("\nMost Profitable Category:", category_profit.idxmax())
# Out:
# Category
# Office Supplies    66179.5379
# Technology         35385.4240
# Furniture          -2714.5353
# Name: Profit, dtype: float64
#
# Most Profitable Category: Office Supplies

# %%
monthly_sales = (
    df_cleaned
    .set_index("Order Date")
    .resample("ME")["Sales"]
    .sum()
)

print("Best Sales Month:", monthly_sales.idxmax())
print("Best Month Sales:", round(monthly_sales.max(), 2))
# Out:
# Best Sales Month: 2017-09-30 00:00:00
# Best Month Sales: 37662.64

# %%
print("KEY INSIGHTS")
print("1. The dataset contains", len(df_cleaned), "cleaned records.")
print("2. The category with the highest sales is:", category_sales.idxmax())
print("3. The region with the highest sales is:", region_sales.idxmax())
print("4. The most profitable category is:", category_profit.idxmax())
print("5. The month with the highest sales is:", monthly_sales.idxmax().strftime("%B %Y"))
# Out:
# KEY INSIGHTS
# 1. The dataset contains 8827 cleaned records.
# 2. The category with the highest sales is: Office Supplies
# 3. The region with the highest sales is: West
# 4. The most profitable category is: Office Supplies
# 5. The month with the highest sales is: September 2017

# %%
df_cleaned.to_csv("../data/Superstore_Cleaned.csv", index=False)

print("FINAL CLEANED DATASET SAVED SUCCESSFULLY!")
# Out:
# FINAL CLEANED DATASET SAVED SUCCESSFULLY!
